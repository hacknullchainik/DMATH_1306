# %%
from Integers import *
from Dtypes import *
ili = [Integer('1'+'0'*500)]
ili.append(Integer('0'*500))
ili.append(Integer('-10'+'1'*500))
ili.append(Integer('9'*500))
n1 = NNumber('0000'*1000)
n2 = NNumber('123'*100)

# %%
print('\n'.join([i.__str__() for i in ili]))
print(n1,n2,sep='\n')
# Out:
# ...
# 0
# -...
# ...
# 0
# 

# %%
print('\n'.join([str(POZ_Z_D(i)) for i in ili]))
# Out:
# 2
# 0
# 1
# 2

# %%
print('\n'.join([MUL_ZM_Z(i).__str__() for i in ili]))
# Out:
# -...
# 0
# ...
# -...

# %%
print('\n'.join([POZ_Z_D(i).__str__() for i in ili]))
# Out:
# 2
# 0
# 1
# 2

# %%
print('\n'.join([TRANS_Z_N(i).__str__() for i in ili]))
# Out:
# ...
# 0
# ...
# ...
